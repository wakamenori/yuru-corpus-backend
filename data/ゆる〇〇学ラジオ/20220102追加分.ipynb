# %%
import pandas as pd
from pytube import YouTube

# %%
video_info_list = [
    {"url" : "https://www.youtube.com/watch?v=03tcrym0u40", "title" : '「クリスマスの星」は"夏"の大三角の中にある？冬なのに？#1', "channel": "ゆる天文学ラジオ"},
    {"url" : "https://www.youtube.com/watch?v=5BpEBdds8AU", "title" :  "【エモい論文】ハチでサイパン島を救った知られざる英雄について #1", "channel": "ゆる生態学ラジオ"},
    {"url" : "https://www.youtube.com/watch?v=2G76X4m5Apw", "title" :  "【非モテの生存戦略】モテない男は生き物から学ぼう！#2", "channel": "ゆる生態学ラジオ"},
    {"url" : "https://www.youtube.com/watch?v=xDYa0YqPTAQ", "title" :  "【難聴・自殺・社会問題】音楽の天才が過ごした過酷すぎる人生【ベートーヴェン】#1", "channel": "ゆる音楽学ラジオ"},
    {"url" : "https://www.youtube.com/watch?v=tzB966BElac", "title" :  "サンタクロースを漢字で書ける？日本最古のサンタ文献で爆笑しよう！#1", "channel": "ゆる書道学ラジオ"},
    {"url" : "https://www.youtube.com/watch?v=Hu_bM1ghryc", "title" :  "酒に狂った書家は壁に文字を書きなぐるし、借金取りと飲み歩く#2", "channel": "ゆる書道学ラジオ"},
    {"url" : "https://www.youtube.com/watch?v=_kznPUyxH6o", "title" :  "忌み言葉は「壁になりたいオタクの心理」【忌み言葉1】#1", "channel": "ゆる民俗学ラジオ"},
    {"url" : "https://www.youtube.com/watch?v=mwzxUbTgydo", "title" :  "忌み言葉で分かるあの世の場所【忌み言葉2】#2", "channel": "ゆる民俗学ラジオ"},
    {'url': "https://www.youtube.com/watch?v=hLO7HIF36oU", "title" : "星座の命名ひどすぎない？納得できない星座の形クイズ！ #2", "channel": "ゆる天文学ラジオ"},
    {"url": "https://www.youtube.com/watch?v=E1-b2BTS3bs", "title": "第九を聴いたとき、「分かってる！」感のある一言は？【第九】#2",  "channel": "ゆる音楽学ラジオ"},
    {"url": "https://www.youtube.com/watch?v=mBeEBjYvQB4", "title": "民俗学の父・柳田國男への反撃は「餅」だった【餅が変えた民俗学】#3", "channel": "ゆる民俗学ラジオ"},
]

# %%
from dataclasses import dataclass, asdict
from tqdm import tqdm



@dataclass
class VideoData:
    Title: str
    ThumbnailUrl: str
    VideoUrl: str
    PublicationDate: str
    Channel: str
    IsAnalyzed: str
    
video_data = []
    
# for video, url in tqdm(zip(all_videos_playlist.videos,all_videos_playlist.url_generator())):
for video_info in video_info_list:
    video = YouTube(video_info["url"])
    
    v = VideoData(
        Title=video_info["title"],
        ThumbnailUrl=video.thumbnail_url,
        VideoUrl=video_info["url"],
        PublicationDate=video.publish_date,
        Channel=video_info["channel"],
        IsAnalyzed=True
    )
    video_data.append(asdict(v))



df = pd.DataFrame(video_data)
df.index.name="Id"
df.index += 176
df
# Out:
#                                         Title  \
# Id
# 176            「クリスマスの星」は"夏"の大三角の中にある？冬なのに？#1
# 177         【エモい論文】ハチでサイパン島を救った知られざる英雄について #1
# 178               【非モテの生存戦略】モテない男は生き物から学ぼう！#2
# 179  【難聴・自殺・社会問題】音楽の天才が過ごした過酷すぎる人生【ベートーヴェン】#1
# 180        サンタクロースを漢字で書ける？日本最古のサンタ文献で爆笑しよう！#1
# 181           酒に狂った書家は壁に文字を書きなぐるし、借金取りと飲み歩く#2
# 182              忌み言葉は「壁になりたいオタクの心理」【忌み言葉1】#1
# 183                   忌み言葉で分かるあの世の場所【忌み言葉2】#2
# 184             星座の命名ひどすぎない？納得できない星座の形クイズ！ #2
# 185           第九を聴いたとき、「分かってる！」感のある一言は？【第九】#2
# 186         民俗学の父・柳田國男への反撃は「餅」だった【餅が変えた民俗学】#3
#
#                                          ThumbnailUrl  \
# Id
# 176  https://i.ytimg.com/vi/03tcrym0u40/sddefault.jpg
# 177  https://i.ytimg.com/vi/5BpEBdds8AU/sddefault.jpg
# 178  https://i.ytimg.com/vi/2G76X4m5Apw/sddefault.jpg
# 179  https://i.ytimg.com/vi/xDYa0YqPTAQ/sddefault.jpg
# 180  https://i.ytimg.com/vi/tzB966BElac/sddefault.jpg
# 181  https://i.ytimg.com/vi/Hu_bM1ghryc/sddefault.jpg
# 182  https://i.ytimg.com/vi/_kznPUyxH6o/sddefault.jpg
# 183  https://i.ytimg.com/vi/mwzxUbTgydo/sddefault.jpg
# 184  https://i.ytimg.com/vi/hLO7HIF36oU/sddefault.jpg
# 185  https://i.ytimg.com/vi/E1-b2BTS3bs/sddefault.jpg
# 186  https://i.ytimg.com/vi/mBeEBjYvQB4/sddefault.jpg
#
#                                         VideoUrl PublicationDate   Channel  \
# Id
# 176  https://www.youtube.com/watch?v=03tcrym0u40      2022-12-23  ゆる天文学ラジオ
# 177  https://www.youtube.com/watch?v=5BpEBdds8AU      2022-12-23  ゆる生態学ラジオ
# 178  https://www.youtube.com/watch?v=2G76X4m5Apw      2022-12-28  ゆる生態学ラジオ
# 179  https://www.youtube.com/watch?v=xDYa0YqPTAQ      2022-12-23  ゆる音楽学ラジオ
# 180  https://www.youtube.com/watch?v=tzB966BElac      2022-12-23  ゆる書道学ラジオ
# 181  https://www.youtube.com/watch?v=Hu_bM1ghryc      2022-12-26  ゆる書道学ラジオ
# 182  https://www.youtube.com/watch?v=_kznPUyxH6o      2022-12-23  ゆる民俗学ラジオ
# 183  https://www.youtube.com/watch?v=mwzxUbTgydo      2022-12-25  ゆる民俗学ラジオ
# 184  https://www.youtube.com/watch?v=hLO7HIF36oU      2022-12-29  ゆる天文学ラジオ
# 185  https://www.youtube.com/watch?v=E1-b2BTS3bs      2022-12-30  ゆる音楽学ラジオ
# 186  https://www.youtube.com/watch?v=mBeEBjYvQB4      2023-01-01  ゆる民俗学ラジオ
#
#      IsAnalyzed
# Id
# 176        True
# 177        True
# 178        True
# 179        True
# 180        True
# 181        True
# 182        True
# 183        True
# 184        True
# 185        True
# 186        True

# %%
df.to_csv("その他_summary.csv")

# %%
summary = pd.read_csv("summary.csv")
summary = summary.set_index("Id")

# %%
summary.index
# Out:
# Int64Index([176, 177, 178, 179, 180, 181, 182, 183, 184, 185, 186], dtype='int64', name='Id')

# %%
from tqdm import tqdm
import os

filenames = os.listdir("../text/processing/")
# def get_text_filepath(filename: str):
#     cwd = os.getcwd()
#     parent = "/".join(os.getcwd().split("/")[:-1])
#     return os.path.join(parent, filename)

def convert_1d_to_2d(l, cols):
    return [l[i : i + cols] for i in range(0, len(l), cols)]


def read_file(filename: str):
    with open(filename, "r") as f:
        lines = f.readlines()[2:-1]
    lines = [line.replace("\n", "") for line in lines if line != "\n"]
    lines_2d = convert_1d_to_2d(lines, 2)
    return lines_2d


def extract_info(line):
    timestamp = line[0].split(".")[0]
    if len(timestamp) == 5:
        timestamp = "00:" + timestamp
    text = line[1]
    return timestamp, text


def get_episode_id(title: str):
    matched = episode[episode["Title"] == normalize(title)]
    if len(matched) == 0:
        raise ValueError(title)
    return matched.index[0]


morphemes = []

for episode_id in tqdm(summary.index):

    # episode_id = get_episode_id(".".join(filename.split(".")[:-1]))
    # print(filename, episode_id)
    lines = read_file(str(episode_id) + ".vtt")
    for line in lines:
        timestamp, text = extract_info(line)
        record = {
            "Type": "Morpheme",
            "Id": f"{episode_id}#{timestamp}#0",
            "Token": text,
            "Speaker": ""
        }
        morphemes.append(record)

others_morphemes_df = pd.DataFrame(morphemes)
others_morphemes_df = others_morphemes_df.drop_duplicates(subset=["Id"])
# morphemes_df.to_csv("../processing/morphemes_processing.csv", index=False)
others_morphemes_df
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 11/11 [00:00<00:00, 228.18it/s]
#           Type              Id                       Token Speaker
# 0     Morpheme  176#00:00:00#0                     【ピカチュウ】
# 1     Morpheme  176#00:00:06#0               白鳥座とはピカチュウである
# 2     Morpheme  176#00:00:09#0                          はぁ
# 3     Morpheme  176#00:00:10#0                        【笑い】
# 4     Morpheme  176#00:00:11#0                     【ピカチュウ】
# ...        ...             ...                         ...     ...
# 8749  Morpheme  186#00:33:16#0  年の初めですので何かを始めるのにはうってつきですよね
# 8750  Morpheme  186#00:33:20#0                ぜひよろしくお願いします
# 8751  Morpheme  186#00:33:22#0    というわけで今回は民族学ラジオ終わりにいたします
# 8752  Morpheme  186#00:33:25#0                  ありがとうございます
# 8753  Morpheme  186#00:33:27#0              深井 ありがとうございました
#
# [8649 rows x 4 columns]

# %%
others_morphemes_df.to_csv("その他_morphemes.csv", index=False)

# %%
from tqdm import tqdm
import numpy as np
spaces = pd.read_csv("../space.csv")
parentheses = pd.read_csv("../【】.csv")

# morphemes_df = pd.read_csv("../morphemes.csv")

def normalize(morphemes_df):
    for space in tqdm(spaces.itertuples()):
        def retrieve(token: str):
            if token.startswith(space.text):
                return token[len(space)+1:]
            return token
        try:
            morphemes_df["Token"] = np.vectorize(retrieve)(morphemes_df["Token"])
        except:
            print(space)
            continue


    for parenthes in tqdm(parentheses.itertuples()):
        def retrieve(token: str):
            return token.replace(parenthes.text, "")

        morphemes_df["Token"] = np.vectorize(retrieve)(morphemes_df["Token"])


    def retrieve(token: str):
            return token.replace("】", "").replace("【", "")


    morphemes_df["Token"] = np.vectorize(retrieve)(morphemes_df["Token"])
    morphemes_df = morphemes_df[morphemes_df["Token"] != ""]
    morphemes_df["Speaker"] = ""
    morphemes_df = morphemes_df.sort_values("Id")
    return others_morphemes_df

others_normalized = normalize(others_morphemes_df)
# Out:
# 11it [00:00, 63.50it/s]
# 46it [00:00, 94.04it/s]
# /var/folders/05/r1dvl9ys0hj3zt3k7jygrzx40000gn/T/ipykernel_42493/677893070.py:34: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   morphemes_df["Speaker"] = ""

# %%
others_normalized.to_json("others.json", orient='records', force_ascii=False)

# %%
from pytube import Playlist

p = Playlist("https://youtube.com/playlist?list=PLzTblKuSqc_ynXDKUWs5VLMXQDREb6BHw")

from dataclasses import dataclass, asdict
from tqdm import tqdm

@dataclass
class VideoData:
    Title: str
    ThumbnailUrl: str
    VideoUrl: str
    PublicationDate: str
    Channel: str
    
video_data = []
    
for video, url in tqdm(zip(p.videos,p.url_generator())):
    v = VideoData(
        Title=video.title,
        ThumbnailUrl=video.thumbnail_url,
        VideoUrl=url,
        PublicationDate=video.publish_date,
        Channel="ゆる言語学ラジオ",
    )
    video_data.append(asdict(v))

com_summary_df = pd.DataFrame(video_data)
com_summary_df
# Out:
# 23it [00:25,  1.09s/it]
#                                                 Title  \
# 0       虹にはオス・メスがあるし、昔はマラリアを注射してた【うんちくしりとりパンクラチオン】#33
# 1              言語学とコンピュータ科学の共通点は、赤ちゃん。【赤ちゃんの言語以外】#147
# 2                     慶應SFCでゲスト講義してきた【出張ゆる言語学ラジオ】#148
# 3                    「学び」研究の第一人者の言葉が重すぎる【今井先生雑談回】#149
# 4   子どもの言い間違い「つめたまる」が素晴らしすぎる【赤ちゃんミステイクアワード2 with今井...
# 5   【ゲーム実況③】単語の解読が困難すぎて苦悩するゲーム【7days to end with y...
# 6                 飲み会よりも読書を優先するコンビによる2022年ベスト本紹介 #174
# 7                  サポーターと奴隷合宿をしたら竹刀が持ち込まれた話【奴隷合宿】#175
# 8           気になる言葉について90分ふざけながら講演しました【出張ゆる言語学ラジオ】#176
# 9                韓国語は日本語のパラレルワールド？【記述言語学者から見た言語1】#177
# 10       記述言語学者が語る、世界で日本語にしかない特徴は？【記述言語学者から見た言語2】#178
# 11     【飢餓・マラリア・ロケット弾】凄腕作家の危険すぎる語学体験【高野秀行さんゲスト雑談】#179
# 12                     【ウビフ語】言語学者の間で有名な言語10選【ホピ語】#180
# 13               言語学者がオシャレな論文名を全力で紹介【薄幸のベネファクティブ】#181
# 14                    【言語沼】ゆる言語学ラジオの本が出ました！【執筆裏話】#182
# 15                           90分ひたすら辞書を読んで盛り上がる回 #183
# 16     語源オタクが最も感動したエモい語源「opportunity」【ターゲット1900⑥】#184
# 17  【ゲーム実況④】記述言語学者と未知の言語解読ゲーム【7days to end with yo...
# 18      DeepL翻訳が出した存在しない四字熟語「別日同腹」が怖すぎる【おたよりを読む回】#186
# 19                       手話に対する間違ったイメージを一新する【手話1】#187
# 20                      宇宙人は手話で会話をしているかもしれない【手話2】#188
# 21               熊本の方言「しこった」は下ネタじゃない【ベスト方言グランプリ3】#189
# 22                       年末だから、夢を語っても許されるよね？【雑談回】#190
#
#                                         ThumbnailUrl  \
# 0   https://i.ytimg.com/vi/bDVpBNIXXh4/sddefault.jpg
# 1   https://i.ytimg.com/vi/gPeqJGMSB2A/sddefault.jpg
# 2   https://i.ytimg.com/vi/nh6Ru3TQMzo/sddefault.jpg
# 3   https://i.ytimg.com/vi/6AO_a9H5gTY/sddefault.jpg
# 4   https://i.ytimg.com/vi/ivG_fbmuV5M/sddefault.jpg
# 5   https://i.ytimg.com/vi/RTO89LjFUKw/sddefault.jpg
# 6   https://i.ytimg.com/vi/yZTjFVnmTaw/sddefault.jpg
# 7   https://i.ytimg.com/vi/a1Z0zP-r-yQ/sddefault.jpg
# 8   https://i.ytimg.com/vi/UJLMyeqm1Ys/sddefault.jpg
# 9   https://i.ytimg.com/vi/IR0iK5D1xlE/sddefault.jpg
# 10  https://i.ytimg.com/vi/_Mis8HokuhQ/sddefault.jpg
# 11  https://i.ytimg.com/vi/QYJgtpVVu-I/sddefault.jpg
# 12  https://i.ytimg.com/vi/tvqAcsay9qA/sddefault.jpg
# 13  https://i.ytimg.com/vi/9NZPwACPpbQ/sddefault.jpg
# 14  https://i.ytimg.com/vi/qY2RrfwTqXg/sddefault.jpg
# 15  https://i.ytimg.com/vi/Ohoo0cjmAUI/sddefault.jpg
# 16  https://i.ytimg.com/vi/malHm23v-Y4/sddefault.jpg
# 17  https://i.ytimg.com/vi/pUiOJFc19pg/sddefault.jpg
# 18  https://i.ytimg.com/vi/xaDxvchr78s/sddefault.jpg
# 19  https://i.ytimg.com/vi/L8JOs6BM94k/sddefault.jpg
# 20  https://i.ytimg.com/vi/6mZWR7GV0is/sddefault.jpg
# 21  https://i.ytimg.com/vi/1dY8Uy7YB9s/sddefault.jpg
# 22  https://i.ytimg.com/vi/GO-v6xLxonk/sddefault.jpg
#
#                                        VideoUrl PublicationDate   Channel
# 0   https://www.youtube.com/watch?v=bDVpBNIXXh4      2021-06-29  ゆる言語学ラジオ
# 1   https://www.youtube.com/watch?v=gPeqJGMSB2A      2022-08-02  ゆる言語学ラジオ
# 2   https://www.youtube.com/watch?v=nh6Ru3TQMzo      2022-08-05  ゆる言語学ラジオ
# 3   https://www.youtube.com/watch?v=6AO_a9H5gTY      2022-08-09  ゆる言語学ラジオ
# 4   https://www.youtube.com/watch?v=ivG_fbmuV5M      2022-08-12  ゆる言語学ラジオ
# 5   https://www.youtube.com/watch?v=RTO89LjFUKw      2022-09-27  ゆる言語学ラジオ
# 6   https://www.youtube.com/watch?v=yZTjFVnmTaw      2022-11-04  ゆる言語学ラジオ
# 7   https://www.youtube.com/watch?v=a1Z0zP-r-yQ      2022-11-08  ゆる言語学ラジオ
# 8   https://www.youtube.com/watch?v=UJLMyeqm1Ys      2022-11-11  ゆる言語学ラジオ
# 9   https://www.youtube.com/watch?v=IR0iK5D1xlE      2022-11-15  ゆる言語学ラジオ
# 10  https://www.youtube.com/watch?v=_Mis8HokuhQ      2022-11-18  ゆる言語学ラジオ
# 11  https://www.youtube.com/watch?v=QYJgtpVVu-I      2022-11-22  ゆる言語学ラジオ
# 12  https://www.youtube.com/watch?v=tvqAcsay9qA      2022-11-25  ゆる言語学ラジオ
# 13  https://www.youtube.com/watch?v=9NZPwACPpbQ      2022-11-29  ゆる言語学ラジオ
# 14  https://www.youtube.com/watch?v=qY2RrfwTqXg      2022-12-02  ゆる言語学ラジオ
# 15  https://www.youtube.com/watch?v=Ohoo0cjmAUI      2022-12-06  ゆる言語学ラジオ
# 16  https://www.youtube.com/watch?v=malHm23v-Y4      2022-12-09  ゆる言語学ラジオ
# 17  https://www.youtube.com/watch?v=pUiOJFc19pg      2022-12-13  ゆる言語学ラジオ
# 18  https://www.youtube.com/watch?v=xaDxvchr78s      2022-12-16  ゆる言語学ラジオ
# 19  https://www.youtube.com/watch?v=L8JOs6BM94k      2022-12-20  ゆる言語学ラジオ
# 20  https://www.youtube.com/watch?v=6mZWR7GV0is      2022-12-23  ゆる言語学ラジオ
# 21  https://www.youtube.com/watch?v=1dY8Uy7YB9s      2022-12-27  ゆる言語学ラジオ
# 22  https://www.youtube.com/watch?v=GO-v6xLxonk      2022-12-30  ゆる言語学ラジオ

# %%
com_summary_df.index.name="Id"
com_summary_df.index += 244
com_summary_df.to_csv("ゆる言語学ラジオ_summary.csv")

# %%
from tqdm import tqdm
import os

# def get_text_filepath(filename: str):
#     cwd = os.getcwd()
#     parent = "/".join(os.getcwd().split("/")[:-1])
#     return os.path.join(parent, filename)

def convert_1d_to_2d(l, cols):
    return [l[i : i + cols] for i in range(0, len(l), cols)]


def read_file(filename: str):
    with open(filename, "r") as f:
        lines = f.readlines()[2:-1]
    lines = [line.replace("\n", "") for line in lines if line != "\n"]
    lines_2d = convert_1d_to_2d(lines, 2)
    return lines_2d


def extract_info(line):
    timestamp = line[0].split(".")[0]
    if len(timestamp) == 5:
        timestamp = "00:" + timestamp
    text = line[1]
    return timestamp, text


def get_episode_id(title: str):
    matched = episode[episode["Title"] == normalize(title)]
    if len(matched) == 0:
        raise ValueError(title)
    return matched.index[0]


morphemes = []

for title, episode_id in tqdm(zip(com_summary_df["Title"],com_summary_df.index)):
    # episode_id = get_episode_id(".".join(filename.split(".")[:-1]))
    # print(filename, episode_id)
    try:
        lines = read_file("./ゆる言語学ラジオ/" + str(title) + ".vtt")
    except:
        print("error")
        print(title)
    
    for line in lines:
        timestamp, text = extract_info(line)
        record = {
            "Type": "Morpheme",
            "Id": f"{episode_id}#{timestamp}#0",
            "Token": text,
            "Speaker": ""
        }
        morphemes.append(record)

gengo_morphemes_df = pd.DataFrame(morphemes)
gengo_morphemes_df = gengo_morphemes_df.drop_duplicates(subset=["Id"])
    # morphemes_df.to_csv("../processing/morphemes_processing.csv", index=False)
gengo_morphemes_df
# Out:
# 23it [00:00, 99.26it/s]
#            Type              Id                                       Token  \
# 0      Morpheme  244#00:00:00#0                             うんちくしりとりパンクラチオン
# 1      Morpheme  244#00:00:02#0                                          よっ
# 2      Morpheme  244#00:00:04#0                                     何ですかこれは
# 3      Morpheme  244#00:00:06#0                   うんちくしりとりパンクラチオンという競技を今日はね
# 4      Morpheme  244#00:00:08#0                                  やろうかなと思います
# ...         ...             ...                                         ...
# 29160  Morpheme  266#01:12:01#0                              深井 よろしくお願いします。
# 29161  Morpheme  266#01:12:02#0  ヤンヤン 高評価、チャンネル登録、感想のコメントとかどしどしいただければと思います。
# 29162  Morpheme  266#01:12:06#0                    ヤンヤン 皆さん、今年はありがとうございました。
# 29163  Morpheme  266#01:12:08#0            深井 ありがとうございました。そして来年もよろしくお願いします。
# 29164  Morpheme  266#01:12:10#0                            ヤンヤン よろしくお願いします。
#
#       Speaker
# 0
# 1
# 2
# 3
# 4
# ...       ...
# 29160
# 29161
# 29162
# 29163
# 29164
#
# [29107 rows x 4 columns]

# %%
from tqdm import tqdm
import numpy as np
spaces = pd.read_csv("../space.csv")
parentheses = pd.read_csv("../【】.csv")

morphemes_df = gengo_morphemes_df

for space in tqdm(spaces.itertuples()):
    def retrieve(token: str):
        if token.startswith(space.text):
            return token[len(space)+1:]
        return token
    try:
        morphemes_df["Token"] = np.vectorize(retrieve)(morphemes_df["Token"])
    except:
        print(space)
        continue


for parenthes in tqdm(parentheses.itertuples()):
    def retrieve(token: str):
        return token.replace(parenthes.text, "")

    morphemes_df["Token"] = np.vectorize(retrieve)(morphemes_df["Token"])


def retrieve(token: str):
        return token.replace("】", "").replace("【", "")


morphemes_df["Token"] = np.vectorize(retrieve)(morphemes_df["Token"])
morphemes_df = morphemes_df[morphemes_df["Token"] != ""]
morphemes_df["Speaker"] = ""
morphemes_df = morphemes_df.sort_values("Id")
morphemes_df
# Out:
# 11it [00:00, 16.44it/s]
# 46it [00:02, 19.02it/s]
# /var/folders/05/r1dvl9ys0hj3zt3k7jygrzx40000gn/T/ipykernel_42493/3796426680.py:33: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   morphemes_df["Speaker"] = ""
#            Type              Id                                   Token  \
# 0      Morpheme  244#00:00:00#0                         うんちくしりとりパンクラチオン
# 1      Morpheme  244#00:00:02#0                                      よっ
# 2      Morpheme  244#00:00:04#0                                 何ですかこれは
# 3      Morpheme  244#00:00:06#0               うんちくしりとりパンクラチオンという競技を今日はね
# 4      Morpheme  244#00:00:08#0                              やろうかなと思います
# ...         ...             ...                                     ...
# 29160  Morpheme  266#01:12:01#0                              ろしくお願いします。
# 29161  Morpheme  266#01:12:02#0   高評価、チャンネル登録、感想のコメントとかどしどしいただければと思います。
# 29162  Morpheme  266#01:12:06#0                     皆さん、今年はありがとうございました。
# 29163  Morpheme  266#01:12:08#0            りがとうございました。そして来年もよろしくお願いします。
# 29164  Morpheme  266#01:12:10#0                             よろしくお願いします。
#
#       Speaker
# 0
# 1
# 2
# 3
# 4
# ...       ...
# 29160
# 29161
# 29162
# 29163
# 29164
#
# [29067 rows x 4 columns]

# %%
morphemes_df.to_csv("ゆる言語学ラジオ_morphemes.csv", index=False)

# %%
morphemes_df
# Out:
#            Type              Id                                Token Speaker
# 1      Morpheme  187#00:00:03#0                   あ、ちょっとオープニング間違えたんで
# 2      Morpheme  187#00:00:06#0                                なになに?
# 3      Morpheme  187#00:00:07#0                          やり直していいですか?
# 4      Morpheme  187#00:00:08#0                       いやいやいや間違えるもん何も
# 5      Morpheme  187#00:00:10#0                 いやオープニング間違えたんでやり直します
# ...         ...             ...                                  ...     ...
# 44953  Morpheme  243#00:40:04#0                     っくりしちゃうよ深井さんの 方が
# 44954  Morpheme  243#00:40:15#0  あとはねそもそも新年一発目です けれども2023年もゆるコンピューター
# 44955  Morpheme  243#00:40:20#0                   科学ラジオどうぞよろしくお願いします
# 44956  Morpheme  243#00:40:22#0    よろしくお願いします 以上今回もお願いしますありがとうございました
# 44957  Morpheme  243#00:40:25#0                           りがとうございました
#
# [44668 rows x 4 columns]

# %%
others_summary = pd.read_csv("その他_summary.csv")
com_summary = pd.read_csv("ゆるコンピュータ科学ラジオ_summary.csv")
gengo_summary = pd.read_csv("ゆる言語学ラジオ_summary.csv")

# %%
all_summary = pd.concat([others_summary, com_summary, gengo_summary])

# %%
all_summary["IsAnalyzed"] = True
all_summary.to_csv("all_summary.csv", index=False)

# %%
others_morphemes = pd.read_csv("その他_morphemes.csv")
com_morphemes = pd.read_csv("ゆるコンピュータ科学ラジオ_morphemes.csv")
gengo_morphemes = pd.read_csv("ゆる言語学ラジオ_morphemes.csv")

# %%
all_morphemes = pd.concat([others_morphemes, com_morphemes, gengo_morphemes])

# %%
all_morphemes.to_csv("all_morphemes.csv", index=False)
